# %%
def compile_and_run_kernel(kernel_number, test_case, analytics=False):
    import os
    
    # Get current working directory
    cwd = os.getcwd()
    
    # Create paths
    kernel_src = os.path.join(cwd, f"cuda_kernels/kernel{kernel_number}.cu")
    kernel_exe = os.path.join(cwd, f"cuda_kernels/bin/kernel{kernel_number}.exe")
    input_file = os.path.join(cwd, f"Input_TestCases/{test_case}.txt")
    output_file = os.path.join(cwd, f"Output_TestCases/{test_case}_k{kernel_number}_o.txt")
    
    # Compile
    # !nvcc "{kernel_src}" -o "{kernel_exe}"
    
     # Run with analytics if requested, otherwise run normally
    if analytics:
        # Create analytics_Bin directory if it doesn't exist
        analytics_dir = os.path.join(cwd, "analytics_Bin")
        os.makedirs(analytics_dir, exist_ok=True)
        
        # Set profile output path inside analytics_Bin folder
        profile_output = os.path.join(analytics_dir, f"profile_k{kernel_number}_{test_case}")
        
        # Run with nsys profiling
        # !nsys profile --sample=none --trace=cuda --force-overwrite=true --stats=true --output="{profile_output}" "{kernel_exe}" "{input_file}" "{output_file}"
        print(f"Analytics data saved to {profile_output}")
    else:
        # Run normally
        !"{kernel_exe}" "{input_file}" "{output_file}"
    
    return output_file

# %% [markdown]
# ### **Requriment - 1**
# - Use only 1 block for your kernel and let the CPU handle the final sum.

# %%
compile_and_run_kernel(1, "t2_50", analytics=True)
# Out:
# kernel1.cu
# tmpxft_00004260_00000000-10_kernel1.cudafe1.cpp
#    Creating library e:\02_Learn\01_University\Senior-1 Spring\Current\Parallel Computing\Labs\Lab_3\Solution\cuda_kernels\bin\kernel1.lib and object e:\02_Learn\01_University\Senior-1 Spring\Current\Parallel Computing\Labs\Lab_3\Solution\cuda_kernels\bin\kernel1.exp
# Collecting data...
# Generating 'C:\Users\basim\AppData\Local\Temp\nsys-report-b633.qdstrm'
#
# [1/6] [0%                          ] profile_k1_t2_50.nsys-rep
# [1/6] [0%                          ] profile_k1_t2_50.nsys-rep
# [1/6] [12%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [11%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [12%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [======34%                   ] profile_k1_t2_50.nsys-rep
# [1/6] [============55%             ] profile_k1_t2_50.nsys-rep
# [1/6] [============54%             ] profile_k1_t2_50.nsys-rep
# [1/6] [===========52%              ] profile_k1_t2_50.nsys-rep
# [1/6] [===========51%              ] profile_k1_t2_50.nsys-rep
# [1/6] [===========50%              ] profile_k1_t2_50.nsys-rep
# [1/6] [==========48%               ] profile_k1_t2_50.nsys-rep
# [1/6] [==========47%               ] profile_k1_t2_50.nsys-rep
# [1/6] [=========46%                ] profile_k1_t2_50.nsys-rep
# [1/6] [=========45%                ] profile_k1_t2_50.nsys-rep
# [1/6] [=========44%                ] profile_k1_t2_50.nsys-rep
# [1/6] [=========43%                ] profile_k1_t2_50.nsys-rep
# [1/6] [========42%                 ] profile_k1_t2_50.nsys-rep
# [1/6] [========41%                 ] profile_k1_t2_50.nsys-rep
# [1/6] [========40%                 ] profile_k1_t2_50.nsys-rep
# [1/6] [=======39%                  ] profile_k1_t2_50.nsys-rep
# [1/6] [=======38%                  ] profile_k1_t2_50.nsys-rep
# [1/6] [=======37%                  ] profile_k1_t2_50.nsys-rep
# [1/6] [=======36%                  ] profile_k1_t2_50.nsys-rep
# [1/6] [======35%                   ] profile_k1_t2_50.nsys-rep
# [1/6] [======34%                   ] profile_k1_t2_50.nsys-rep
# [1/6] [======33%                   ] profile_k1_t2_50.nsys-rep
# [1/6] [=====32%                    ] profile_k1_t2_50.nsys-rep
# [1/6] [=====31%                    ] profile_k1_t2_50.nsys-rep
# [1/6] [=====30%                    ] profile_k1_t2_50.nsys-rep
# [1/6] [=====29%                    ] profile_k1_t2_50.nsys-rep
# [1/6] [====28%                     ] profile_k1_t2_50.nsys-rep
# [1/6] [====27%                     ] profile_k1_t2_50.nsys-rep
# [1/6] [====26%                     ] profile_k1_t2_50.nsys-rep
# [1/6] [====25%                     ] profile_k1_t2_50.nsys-rep
# [1/6] [===24%                      ] profile_k1_t2_50.nsys-rep
# [1/6] [===23%                      ] profile_k1_t2_50.nsys-rep
# [1/6] [===22%                      ] profile_k1_t2_50.nsys-rep
# [1/6] [==21%                       ] profile_k1_t2_50.nsys-rep
# [1/6] [==20%                       ] profile_k1_t2_50.nsys-rep
# [1/6] [==19%                       ] profile_k1_t2_50.nsys-rep
# [1/6] [==18%                       ] profile_k1_t2_50.nsys-rep
# [1/6] [=17%                        ] profile_k1_t2_50.nsys-rep
# [1/6] [=16%                        ] profile_k1_t2_50.nsys-rep
# [1/6] [=17%                        ] profile_k1_t2_50.nsys-rep
# [1/6] [=16%                        ] profile_k1_t2_50.nsys-rep
# [1/6] [=15%                        ] profile_k1_t2_50.nsys-rep
# [1/6] [14%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [=15%                        ] profile_k1_t2_50.nsys-rep
# [1/6] [14%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [=15%                        ] profile_k1_t2_50.nsys-rep
# [1/6] [14%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [=15%                        ] profile_k1_t2_50.nsys-rep
# [1/6] [14%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [13%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [12%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [11%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [12%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [11%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [10%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [9%                          ] profile_k1_t2_50.nsys-rep
# [1/6] [8%                          ] profile_k1_t2_50.nsys-rep
# [1/6] [7%                          ] profile_k1_t2_50.nsys-rep
# [1/6] [6%                          ] profile_k1_t2_50.nsys-rep
# [1/6] [5%                          ] profile_k1_t2_50.nsys-rep
# [1/6] [0%                          ] profile_k1_t2_50.nsys-rep
# [1/6] [6%                          ] profile_k1_t2_50.nsys-rep
# [1/6] [8%                          ] profile_k1_t2_50.nsys-rep
# [1/6] [11%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [14%                         ] profile_k1_t2_50.nsys-rep
# [1/6] [=17%                        ] profile_k1_t2_50.nsys-rep
# [1/6] [==19%                       ] profile_k1_t2_50.nsys-rep
# [1/6] [===22%                      ] profile_k1_t2_50.nsys-rep
# [1/6] [====25%                     ] profile_k1_t2_50.nsys-rep
# [1/6] [====28%                     ] profile_k1_t2_50.nsys-rep
# [1/6] [=====31%                    ] profile_k1_t2_50.nsys-rep
# [1/6] [=====32%                    ] profile_k1_t2_50.nsys-rep
# [1/6] [======33%                   ] profile_k1_t2_50.nsys-rep
# [1/6] [======34%                   ] profile_k1_t2_50.nsys-rep
# [1/6] [=======36%                  ] profile_k1_t2_50.nsys-rep
# [1/6] [=======37%                  ] profile_k1_t2_50.nsys-rep
# [1/6] [=======38%                  ] profile_k1_t2_50.nsys-rep
# [1/6] [========40%                 ] profile_k1_t2_50.nsys-rep
# [1/6] [========41%                 ] profile_k1_t2_50.nsys-rep
# [1/6] [========42%                 ] profile_k1_t2_50.nsys-rep
# [1/6] [=========43%                ] profile_k1_t2_50.nsys-rep
# [1/6] [=========44%                ] profile_k1_t2_50.nsys-rep
# [1/6] [=========46%                ] profile_k1_t2_50.nsys-rep
# [1/6] [==========47%               ] profile_k1_t2_50.nsys-rep
# [1/6] [==========48%               ] profile_k1_t2_50.nsys-rep
# [1/6] [==========49%               ] profile_k1_t2_50.nsys-rep
# [1/6] [===========50%              ] profile_k1_t2_50.nsys-rep
# [1/6] [===========51%              ] profile_k1_t2_50.nsys-rep
# [1/6] [===========52%              ] profile_k1_t2_50.nsys-rep
# [1/6] [===========53%              ] profile_k1_t2_50.nsys-rep
# [1/6] [============54%             ] profile_k1_t2_50.nsys-rep
# [1/6] [============55%             ] profile_k1_t2_50.nsys-rep
# [1/6] [============56%             ] profile_k1_t2_50.nsys-rep
# [1/6] [============57%             ] profile_k1_t2_50.nsys-rep
# [1/6] [=============58%            ] profile_k1_t2_50.nsys-rep
# [1/6] [=============59%            ] profile_k1_t2_50.nsys-rep
# [1/6] [=============60%            ] profile_k1_t2_50.nsys-rep
# [1/6] [==============61%           ] profile_k1_t2_50.nsys-rep
# [1/6] [==============62%           ] profile_k1_t2_50.nsys-rep
# [1/6] [==============63%           ] profile_k1_t2_50.nsys-rep
# [1/6] [==============64%           ] profile_k1_t2_50.nsys-rep
# [1/6] [===============65%          ] profile_k1_t2_50.nsys-rep
# [1/6] [===============66%          ] profile_k1_t2_50.nsys-rep
# [1/6] [===============67%          ] profile_k1_t2_50.nsys-rep
# [1/6] [================68%         ] profile_k1_t2_50.nsys-rep
# [1/6] [================69%         ] profile_k1_t2_50.nsys-rep
# [1/6] [================70%         ] profile_k1_t2_50.nsys-rep
# [1/6] [================71%         ] profile_k1_t2_50.nsys-rep
# [1/6] [=================72%        ] profile_k1_t2_50.nsys-rep
# [1/6] [=================73%        ] profile_k1_t2_50.nsys-rep
# [1/6] [=================74%        ] profile_k1_t2_50.nsys-rep
# [1/6] [==================75%       ] profile_k1_t2_50.nsys-rep
# [1/6] [==================76%       ] profile_k1_t2_50.nsys-rep
# [1/6] [==================77%       ] profile_k1_t2_50.nsys-rep
# [1/6] [==================78%       ] profile_k1_t2_50.nsys-rep
# [1/6] [===================79%      ] profile_k1_t2_50.nsys-rep
# [1/6] [===================80%      ] profile_k1_t2_50.nsys-rep
# [1/6] [===================81%      ] profile_k1_t2_50.nsys-rep
# [1/6] [===================82%      ] profile_k1_t2_50.nsys-rep
# [1/6] [====================83%     ] profile_k1_t2_50.nsys-rep
# [1/6] [====================84%     ] profile_k1_t2_50.nsys-rep
# [1/6] [====================85%     ] profile_k1_t2_50.nsys-rep
# [1/6] [=====================86%    ] profile_k1_t2_50.nsys-rep
# [1/6] [=====================87%    ] profile_k1_t2_50.nsys-rep
# [1/6] [=====================88%    ] profile_k1_t2_50.nsys-rep
# [1/6] [=====================89%    ] profile_k1_t2_50.nsys-rep
# [1/6] [======================90%   ] profile_k1_t2_50.nsys-rep
# [1/6] [======================91%   ] profile_k1_t2_50.nsys-rep
# [1/6] [======================92%   ] profile_k1_t2_50.nsys-rep
# [1/6] [=======================93%  ] profile_k1_t2_50.nsys-rep
# [1/6] [=======================94%  ] profile_k1_t2_50.nsys-rep
# [1/6] [=======================95%  ] profile_k1_t2_50.nsys-rep
# [1/6] [=======================96%  ] profile_k1_t2_50.nsys-rep
# [1/6] [========================97% ] profile_k1_t2_50.nsys-rep
# [1/6] [========================98% ] profile_k1_t2_50.nsys-rep
# [1/6] [========================99% ] profile_k1_t2_50.nsys-rep
# [1/6] [========================100%] profile_k1_t2_50.nsys-rep
# [1/6] [========================100%] profile_k1_t2_50.nsys-rep
# [1/6] [========================100%] profile_k1_t2_50.nsys-rep
#
# [2/6] [0%                          ] profile_k1_t2_50.sqlite
# [2/6] [1%                          ] profile_k1_t2_50.sqlite
# [2/6] [2%                          ] profile_k1_t2_50.sqlite
# [2/6] [3%                          ] profile_k1_t2_50.sqlite
# [2/6] [4%                          ] profile_k1_t2_50.sqlite
# [2/6] [5%                          ] profile_k1_t2_50.sqlite
# [2/6] [6%                          ] profile_k1_t2_50.sqlite
# [2/6] [7%                          ] profile_k1_t2_50.sqlite
# [2/6] [8%                          ] profile_k1_t2_50.sqlite
# [2/6] [9%                          ] profile_k1_t2_50.sqlite
# [2/6] [10%                         ] profile_k1_t2_50.sqlite
# [2/6] [11%                         ] profile_k1_t2_50.sqlite
# [2/6] [12%                         ] profile_k1_t2_50.sqlite
# [2/6] [13%                         ] profile_k1_t2_50.sqlite
# [2/6] [14%                         ] profile_k1_t2_50.sqlite
# [2/6] [=15%                        ] profile_k1_t2_50.sqlite
# [2/6] [=16%                        ] profile_k1_t2_50.sqlite
# [2/6] [=17%                        ] profile_k1_t2_50.sqlite
# [2/6] [==18%                       ] profile_k1_t2_50.sqlite
# [2/6] [==19%                       ] profile_k1_t2_50.sqlite
# [2/6] [==20%                       ] profile_k1_t2_50.sqlite
# [2/6] [==21%                       ] profile_k1_t2_50.sqlite
# [2/6] [===22%                      ] profile_k1_t2_50.sqlite
# [2/6] [===23%                      ] profile_k1_t2_50.sqlite
# [2/6] [===24%                      ] profile_k1_t2_50.sqlite
# [2/6] [====25%                     ] profile_k1_t2_50.sqlite
# [2/6] [====26%                     ] profile_k1_t2_50.sqlite
# [2/6] [====27%                     ] profile_k1_t2_50.sqlite
# [2/6] [====28%                     ] profile_k1_t2_50.sqlite
# [2/6] [=====29%                    ] profile_k1_t2_50.sqlite
# [2/6] [=====30%                    ] profile_k1_t2_50.sqlite
# [2/6] [=====31%                    ] profile_k1_t2_50.sqlite
# [2/6] [=====32%                    ] profile_k1_t2_50.sqlite
# [2/6] [======33%                   ] profile_k1_t2_50.sqlite
# [2/6] [======34%                   ] profile_k1_t2_50.sqlite
# [2/6] [======35%                   ] profile_k1_t2_50.sqlite
# [2/6] [=======36%                  ] profile_k1_t2_50.sqlite
# [2/6] [=======37%                  ] profile_k1_t2_50.sqlite
# [2/6] [=======38%                  ] profile_k1_t2_50.sqlite
# [2/6] [=======39%                  ] profile_k1_t2_50.sqlite
# [2/6] [========40%                 ] profile_k1_t2_50.sqlite
# [2/6] [========41%                 ] profile_k1_t2_50.sqlite
# [2/6] [========42%                 ] profile_k1_t2_50.sqlite
# [2/6] [=========43%                ] profile_k1_t2_50.sqlite
# [2/6] [=========44%                ] profile_k1_t2_50.sqlite
# [2/6] [=========45%                ] profile_k1_t2_50.sqlite
# [2/6] [=========46%                ] profile_k1_t2_50.sqlite
# [2/6] [==========47%               ] profile_k1_t2_50.sqlite
# [2/6] [==========48%               ] profile_k1_t2_50.sqlite
# [2/6] [==========49%               ] profile_k1_t2_50.sqlite
# [2/6] [===========50%              ] profile_k1_t2_50.sqlite
# [2/6] [===========51%              ] profile_k1_t2_50.sqlite
# [2/6] [===========52%              ] profile_k1_t2_50.sqlite
# [2/6] [===========53%              ] profile_k1_t2_50.sqlite
# [2/6] [============54%             ] profile_k1_t2_50.sqlite
# [2/6] [============55%             ] profile_k1_t2_50.sqlite
# [2/6] [============56%             ] profile_k1_t2_50.sqlite
# [2/6] [============57%             ] profile_k1_t2_50.sqlite
# [2/6] [=============58%            ] profile_k1_t2_50.sqlite
# [2/6] [=============59%            ] profile_k1_t2_50.sqlite
# [2/6] [=============60%            ] profile_k1_t2_50.sqlite
# [2/6] [==============61%           ] profile_k1_t2_50.sqlite
# [2/6] [==============62%           ] profile_k1_t2_50.sqlite
# [2/6] [==============63%           ] profile_k1_t2_50.sqlite
# [2/6] [==============64%           ] profile_k1_t2_50.sqlite
# [2/6] [===============65%          ] profile_k1_t2_50.sqlite
# [2/6] [===============66%          ] profile_k1_t2_50.sqlite
# [2/6] [===============67%          ] profile_k1_t2_50.sqlite
# [2/6] [================68%         ] profile_k1_t2_50.sqlite
# [2/6] [================69%         ] profile_k1_t2_50.sqlite
# [2/6] [================70%         ] profile_k1_t2_50.sqlite
# [2/6] [================71%         ] profile_k1_t2_50.sqlite
# [2/6] [=================72%        ] profile_k1_t2_50.sqlite
# [2/6] [=================73%        ] profile_k1_t2_50.sqlite
# [2/6] [=================74%        ] profile_k1_t2_50.sqlite
# [2/6] [==================75%       ] profile_k1_t2_50.sqlite
# [2/6] [==================76%       ] profile_k1_t2_50.sqlite
# [2/6] [==================77%       ] profile_k1_t2_50.sqlite
# [2/6] [==================78%       ] profile_k1_t2_50.sqlite
# [2/6] [===================79%      ] profile_k1_t2_50.sqlite
# [2/6] [===================80%      ] profile_k1_t2_50.sqlite
# [2/6] [===================81%      ] profile_k1_t2_50.sqlite
# [2/6] [===================82%      ] profile_k1_t2_50.sqlite
# [2/6] [====================83%     ] profile_k1_t2_50.sqlite
# [2/6] [====================84%     ] profile_k1_t2_50.sqlite
# [2/6] [====================85%     ] profile_k1_t2_50.sqlite
# [2/6] [=====================86%    ] profile_k1_t2_50.sqlite
# [2/6] [=====================87%    ] profile_k1_t2_50.sqlite
# [2/6] [=====================88%    ] profile_k1_t2_50.sqlite
# [2/6] [=====================89%    ] profile_k1_t2_50.sqlite
# [2/6] [======================90%   ] profile_k1_t2_50.sqlite
# [2/6] [======================91%   ] profile_k1_t2_50.sqlite
# [2/6] [======================92%   ] profile_k1_t2_50.sqlite
# [2/6] [=======================93%  ] profile_k1_t2_50.sqlite
# [2/6] [=======================94%  ] profile_k1_t2_50.sqlite
# [2/6] [=======================95%  ] profile_k1_t2_50.sqlite
# [2/6] [=======================96%  ] profile_k1_t2_50.sqlite
# [2/6] [========================97% ] profile_k1_t2_50.sqlite
# [2/6] [========================98% ] profile_k1_t2_50.sqlite
# [2/6] [========================99% ] profile_k1_t2_50.sqlite
# [2/6] [========================100%] profile_k1_t2_50.sqlite
# [2/6] [========================100%] profile_k1_t2_50.sqlite
# [3/6] Executing 'cuda_api_sum' stats report
#
#  Time (%)  Total Time (ns)  Num Calls   Avg (ns)    Med (ns)   Min (ns)  Max (ns)   StdDev (ns)           Name
#  --------  ---------------  ---------  -----------  ---------  --------  ---------  -----------  ----------------------
#      99.1        629244726          3  209748242.0   179238.0      8518  629056970  363132020.5  cudaMalloc
#       0.3          2084086          2    1042043.0  1042043.0    132476    1951610    1286322.0  cudaLaunchKernel
#       0.3          2035467          2    1017733.5  1017733.5     62778    1972689    1350511.0  cudaMemcpy
#       0.2          1290357          3     430119.0   621139.0     25427     643791     350656.5  cudaFree
#       0.0            73539          1      73539.0    73539.0     73539      73539          0.0  cuLibraryUnload
#       0.0             9045          1       9045.0     9045.0      9045       9045          0.0  cuCtxSynchronize
#       0.0             5426          1       5426.0     5426.0      5426       5426          0.0  cuModuleGetLoadingMode
#       0.0              700          1        700.0      700.0       700        700          0.0  cuDeviceGetLuid
#
# [4/6] Executing 'cuda_gpu_kern_sum' stats report
#
#  Time (%)  Total Time (ns)  Instances  Avg (ns)  Med (ns)  Min (ns)  Max (ns)  StdDev (ns)                                              Name
#  --------  ---------------  ---------  --------  --------  --------  --------  -----------  ---------------------------------------------------------------------------------------------
#      73.2            18593          1   18593.0   18593.0     18593     18593          0.0  sumZDimension(double *, double *, unsigned long long, unsigned long long, unsigned long long)
#      26.8             6816          1    6816.0    6816.0      6816      6816          0.0  reduce2DTo1D(double *, double *, unsigned long long, unsigned long long)
#
# [5/6] Executing 'cuda_gpu_mem_time_sum' stats report
#
#  Time (%)  Total Time (ns)  Count  Avg (ns)   Med (ns)   Min (ns)  Max (ns)  StdDev (ns)           Operation
#  --------  ---------------  -----  ---------  ---------  --------  --------  -----------  ----------------------------
#      99.9          1286493      1  1286493.0  1286493.0   1286493   1286493          0.0  [CUDA memcpy Host-to-Device]
#       0.1             1376      1     1376.0     1376.0      1376      1376          0.0  [CUDA memcpy Device-to-Host]
#
# [6/6] Executing 'cuda_gpu_mem_size_sum' stats report
#
#  Total (MB)  Count  Avg (MB)  Med (MB)  Min (MB)  Max (MB)  StdDev (MB)           Operation
#  ----------  -----  --------  --------  --------  --------  -----------  ----------------------------
#       8.000      1     8.000     8.000     8.000     8.000        0.000  [CUDA memcpy Host-to-Device]
#       0.001      1     0.001     0.001     0.001     0.001        0.000  [CUDA memcpy Device-to-Host]
#
# Generated:
#     e:\02_Learn\01_University\Senior-1 Spring\Current\Parallel Computing\Labs\Lab_3\Solution\profile_k1_t2_50.nsys-rep
#     e:\02_Learn\01_University\Senior-1 Spring\Current\Parallel Computing\Labs\Lab_3\Solution\profile_k1_t2_50.sqlite
# Analytics data saved to profile_k1_t2_50
# 'e:\\02_Learn\\01_University\\Senior-1 Spring\\Current\\Parallel Computing\\Labs\\Lab_3\\Solution\\Output_TestCases/t2_50_k1_o.txt'

# %% [markdown]
# ### **Requriment - 2**
# - Use only 1 block for your kernal and let one thread to handle the final sum.

# %%
compile_and_run_kernel(2, "t2_50", analytics=True)
# Out:
# kernel2.cu
# tmpxft_00003494_00000000-10_kernel2.cudafe1.cpp
#    Creating library e:\02_Learn\01_University\Senior-1 Spring\Current\Parallel Computing\Labs\Lab_3\Solution\cuda_kernels\bin\kernel2.lib and object e:\02_Learn\01_University\Senior-1 Spring\Current\Parallel Computing\Labs\Lab_3\Solution\cuda_kernels\bin\kernel2.exp
# ^C
# Analytics data saved to profile_k2_t2_50
# 'e:\\02_Learn\\01_University\\Senior-1 Spring\\Current\\Parallel Computing\\Labs\\Lab_3\\Solution\\Output_TestCases/t2_50_k2_o.txt'
# Collecting data...
# Generating 'C:\Users\basim\AppData\Local\Temp\nsys-report-5cd4.qdstrm'
#
# [1/6] [0%                          ] profile_k2_t2_50.nsys-rep
# [1/6] [0%                          ] profile_k2_t2_50.nsys-rep
# [1/6] [10%                         ] profile_k2_t2_50.nsys-rep
# [1/6] [9%                          ] profile_k2_t2_50.nsys-rep
# [1/6] [8%                          ] profile_k2_t2_50.nsys-rep
# [1/6] [7%                          ] profile_k2_t2_50.nsys-rep
# [1/6] [6%                          ] profile_k2_t2_50.nsys-rep
# [1/6] [5%                          ] profile_k2_t2_50.nsys-rep
# [1/6] [0%                          ] profile_k2_t2_50.nsys-rep
# [1/6] [7%                          ] profile_k2_t2_50.nsys-rep
# [1/6] [10%                         ] profile_k2_t2_50.nsys-rep
# [1/6] [14%                         ] profile_k2_t2_50.nsys-rep
# [1/6] [==18%                       ] profile_k2_t2_50.nsys-rep
# [1/6] [==21%                       ] profile_k2_t2_50.nsys-rep
# [1/6] [====25%                     ] profile_k2_t2_50.nsys-rep
# [1/6] [=====29%                    ] profile_k2_t2_50.nsys-rep
# [1/6] [======33%                   ] profile_k2_t2_50.nsys-rep
# [1/6] [=======37%                  ] profile_k2_t2_50.nsys-rep
# [1/6] [========40%                 ] profile_k2_t2_50.nsys-rep
# [1/6] [=========43%                ] profile_k2_t2_50.nsys-rep
# [1/6] [=========46%                ] profile_k2_t2_50.nsys-rep
# [1/6] [==========47%               ] profile_k2_t2_50.nsys-rep
# [1/6] [==========48%               ] profile_k2_t2_50.nsys-rep
# [1/6] [==========49%               ] profile_k2_t2_50.nsys-rep
# [1/6] [===========50%              ] profile_k2_t2_50.nsys-rep
# [1/6] [===========51%              ] profile_k2_t2_50.nsys-rep
# [1/6] [===========52%              ] profile_k2_t2_50.nsys-rep
# [1/6] [===========53%              ] profile_k2_t2_50.nsys-rep
# [1/6] [============54%             ] profile_k2_t2_50.nsys-rep
# [1/6] [============55%             ] profile_k2_t2_50.nsys-rep
# [1/6] [============56%             ] profile_k2_t2_50.nsys-rep
# [1/6] [============57%             ] profile_k2_t2_50.nsys-rep
# [1/6] [=============58%            ] profile_k2_t2_50.nsys-rep
# [1/6] [=============59%            ] profile_k2_t2_50.nsys-rep
# [1/6] [=============60%            ] profile_k2_t2_50.nsys-rep
# [1/6] [==============61%           ] profile_k2_t2_50.nsys-rep
# [1/6] [==============62%           ] profile_k2_t2_50.nsys-rep
# [1/6] [==============63%           ] profile_k2_t2_50.nsys-rep
# [1/6] [==============64%           ] profile_k2_t2_50.nsys-rep
# [1/6] [===============65%          ] profile_k2_t2_50.nsys-rep
# [1/6] [===============66%          ] profile_k2_t2_50.nsys-rep
# [1/6] [===============67%          ] profile_k2_t2_50.nsys-rep
# [1/6] [================68%         ] profile_k2_t2_50.nsys-rep
# [1/6] [================69%         ] profile_k2_t2_50.nsys-rep
# [1/6] [================70%         ] profile_k2_t2_50.nsys-rep
# [1/6] [================71%         ] profile_k2_t2_50.nsys-rep
# [1/6] [=================72%        ] profile_k2_t2_50.nsys-rep
# [1/6] [=================73%        ] profile_k2_t2_50.nsys-rep
# [1/6] [=================74%        ] profile_k2_t2_50.nsys-rep
# [1/6] [==================75%       ] profile_k2_t2_50.nsys-rep
# [1/6] [==================76%       ] profile_k2_t2_50.nsys-rep
# [1/6] [==================77%       ] profile_k2_t2_50.nsys-rep
# [1/6] [==================78%       ] profile_k2_t2_50.nsys-rep
# [1/6] [===================79%      ] profile_k2_t2_50.nsys-rep
# [1/6] [===================80%      ] profile_k2_t2_50.nsys-rep
# [1/6] [===================81%      ] profile_k2_t2_50.nsys-rep
# [1/6] [===================82%      ] profile_k2_t2_50.nsys-rep
# [1/6] [====================83%     ] profile_k2_t2_50.nsys-rep
# [1/6] [====================84%     ] profile_k2_t2_50.nsys-rep
# [1/6] [====================85%     ] profile_k2_t2_50.nsys-rep
# [1/6] [=====================86%    ] profile_k2_t2_50.nsys-rep
# [1/6] [=====================87%    ] profile_k2_t2_50.nsys-rep
# [1/6] [=====================88%    ] profile_k2_t2_50.nsys-rep
# [1/6] [=====================89%    ] profile_k2_t2_50.nsys-rep
# [1/6] [======================90%   ] profile_k2_t2_50.nsys-rep
# [1/6] [======================91%   ] profile_k2_t2_50.nsys-rep
# [1/6] [======================92%   ] profile_k2_t2_50.nsys-rep
# [1/6] [=======================93%  ] profile_k2_t2_50.nsys-rep
# [1/6] [=======================94%  ] profile_k2_t2_50.nsys-rep
# [1/6] [=======================95%  ] profile_k2_t2_50.nsys-rep
# [1/6] [=======================96%  ] profile_k2_t2_50.nsys-rep
# [1/6] [========================97% ] profile_k2_t2_50.nsys-rep
# [1/6] [========================98% ] profile_k2_t2_50.nsys-rep
# [1/6] [========================99% ] profile_k2_t2_50.nsys-rep
# [1/6] [========================100%] profile_k2_t2_50.nsys-rep
# [1/6] [========================100%] profile_k2_t2_50.nsys-rep
# [1/6] [========================100%] profile_k2_t2_50.nsys-rep
#
# [2/6] [0%                          ] profile_k2_t2_50.sqlite
# [2/6] [1%                          ] profile_k2_t2_50.sqlite
# [2/6] [2%                          ] profile_k2_t2_50.sqlite
# [2/6] [3%                          ] profile_k2_t2_50.sqlite
# [2/6] [4%                          ] profile_k2_t2_50.sqlite
# [2/6] [5%                          ] profile_k2_t2_50.sqlite
# [2/6] [6%                          ] profile_k2_t2_50.sqlite
# [2/6] [7%                          ] profile_k2_t2_50.sqlite
# [2/6] [8%                          ] profile_k2_t2_50.sqlite
# [2/6] [9%                          ] profile_k2_t2_50.sqlite
# [2/6] [10%                         ] profile_k2_t2_50.sqlite
# [2/6] [11%                         ] profile_k2_t2_50.sqlite
# [2/6] [12%                         ] profile_k2_t2_50.sqlite
# [2/6] [13%                         ] profile_k2_t2_50.sqlite
# [2/6] [14%                         ] profile_k2_t2_50.sqlite
# [2/6] [=15%                        ] profile_k2_t2_50.sqlite
# [2/6] [=16%                        ] profile_k2_t2_50.sqlite
# [2/6] [=17%                        ] profile_k2_t2_50.sqlite
# [2/6] [==18%                       ] profile_k2_t2_50.sqlite
# [2/6] [==19%                       ] profile_k2_t2_50.sqlite
# [2/6] [==20%                       ] profile_k2_t2_50.sqlite
# [2/6] [==21%                       ] profile_k2_t2_50.sqlite
# [2/6] [===22%                      ] profile_k2_t2_50.sqlite
# [2/6] [===23%                      ] profile_k2_t2_50.sqlite
# [2/6] [===24%                      ] profile_k2_t2_50.sqlite
# [2/6] [====25%                     ] profile_k2_t2_50.sqlite
# [2/6] [====26%                     ] profile_k2_t2_50.sqlite
# [2/6] [====27%                     ] profile_k2_t2_50.sqlite
# [2/6] [====28%                     ] profile_k2_t2_50.sqlite
# [2/6] [=====29%                    ] profile_k2_t2_50.sqlite
# [2/6] [=====30%                    ] profile_k2_t2_50.sqlite
# [2/6] [=====31%                    ] profile_k2_t2_50.sqlite
# [2/6] [=====32%                    ] profile_k2_t2_50.sqlite
# [2/6] [======33%                   ] profile_k2_t2_50.sqlite
# [2/6] [======34%                   ] profile_k2_t2_50.sqlite
# [2/6] [======35%                   ] profile_k2_t2_50.sqlite
# [2/6] [=======36%                  ] profile_k2_t2_50.sqlite
# [2/6] [=======37%                  ] profile_k2_t2_50.sqlite
# [2/6] [=======38%                  ] profile_k2_t2_50.sqlite
# [2/6] [=======39%                  ] profile_k2_t2_50.sqlite
# [2/6] [========40%                 ] profile_k2_t2_50.sqlite
# [2/6] [========41%                 ] profile_k2_t2_50.sqlite
# [2/6] [========42%                 ] profile_k2_t2_50.sqlite
# [2/6] [=========43%                ] profile_k2_t2_50.sqlite
# [2/6] [=========44%                ] profile_k2_t2_50.sqlite
# [2/6] [=========45%                ] profile_k2_t2_50.sqlite
# [2/6] [=========46%                ] profile_k2_t2_50.sqlite
# [2/6] [==========47%               ] profile_k2_t2_50.sqlite
# [2/6] [==========48%               ] profile_k2_t2_50.sqlite
# [2/6] [==========49%               ] profile_k2_t2_50.sqlite
# [2/6] [===========50%              ] profile_k2_t2_50.sqlite
# [2/6] [===========51%              ] profile_k2_t2_50.sqlite
# [2/6] [===========52%              ] profile_k2_t2_50.sqlite
# [2/6] [===========53%              ] profile_k2_t2_50.sqlite
# [2/6] [============54%             ] profile_k2_t2_50.sqlite
# [2/6] [============55%             ] profile_k2_t2_50.sqlite
# [2/6] [============56%             ] profile_k2_t2_50.sqlite
# [2/6] [============57%             ] profile_k2_t2_50.sqlite
# [2/6] [=============58%            ] profile_k2_t2_50.sqlite
# [2/6] [=============59%            ] profile_k2_t2_50.sqlite
# [2/6] [=============60%            ] profile_k2_t2_50.sqlite
# [2/6] [==============61%           ] profile_k2_t2_50.sqlite
# [2/6] [==============62%           ] profile_k2_t2_50.sqlite
# [2/6] [==============63%           ] profile_k2_t2_50.sqlite
# [2/6] [==============64%           ] profile_k2_t2_50.sqlite
# [2/6] [===============65%          ] profile_k2_t2_50.sqlite
# [2/6] [===============66%          ] profile_k2_t2_50.sqlite
# [2/6] [===============67%          ] profile_k2_t2_50.sqlite
# [2/6] [================68%         ] profile_k2_t2_50.sqlite
# [2/6] [================69%         ] profile_k2_t2_50.sqlite
# [2/6] [================70%         ] profile_k2_t2_50.sqlite
# [2/6] [================71%         ] profile_k2_t2_50.sqlite
# [2/6] [=================72%        ] profile_k2_t2_50.sqlite
# [2/6] [=================73%        ] profile_k2_t2_50.sqlite
# [2/6] [=================74%        ] profile_k2_t2_50.sqlite
# [2/6] [==================75%       ] profile_k2_t2_50.sqlite
# [2/6] [==================76%       ] profile_k2_t2_50.sqlite
# [2/6] [==================77%       ] profile_k2_t2_50.sqlite
# [2/6] [==================78%       ] profile_k2_t2_50.sqlite
# [2/6] [===================79%      ] profile_k2_t2_50.sqlite
# [2/6] [===================80%      ] profile_k2_t2_50.sqlite
# [2/6] [===================81%      ] profile_k2_t2_50.sqlite
# [2/6] [===================82%      ] profile_k2_t2_50.sqlite
# [2/6] [====================83%     ] profile_k2_t2_50.sqlite
# [2/6] [====================84%     ] profile_k2_t2_50.sqlite
# [2/6] [====================85%     ] profile_k2_t2_50.sqlite
# [2/6] [=====================86%    ] profile_k2_t2_50.sqlite
# [2/6] [=====================87%    ] profile_k2_t2_50.sqlite
# [2/6] [=====================88%    ] profile_k2_t2_50.sqlite
# [2/6] [=====================89%    ] profile_k2_t2_50.sqlite
# [2/6] [======================90%   ] profile_k2_t2_50.sqlite
# [2/6] [======================91%   ] profile_k2_t2_50.sqlite
# [2/6] [======================92%   ] profile_k2_t2_50.sqlite
# [2/6] [=======================93%  ] profile_k2_t2_50.sqlite
# [2/6] [=======================94%  ] profile_k2_t2_50.sqlite
# [2/6] [=======================95%  ] profile_k2_t2_50.sqlite
# [2/6] [=======================96%  ] profile_k2_t2_50.sqlite
# [2/6] [========================97% ] profile_k2_t2_50.sqlite
# [2/6] [========================98% ] profile_k2_t2_50.sqlite
# [2/6] [========================99% ] profile_k2_t2_50.sqlite
# [2/6] [========================100%] profile_k2_t2_50.sqlite
# [2/6] [========================100%] profile_k2_t2_50.sqlite
# [3/6] Executing 'cuda_api_sum' stats report
#
#  Time (%)  Total Time (ns)  Num Calls   Avg (ns)    Med (ns)  Min (ns)  Max (ns)   StdDev (ns)           Name
#  --------  ---------------  ---------  -----------  --------  --------  ---------  -----------  ----------------------
#      99.2        645336605          3  215112201.7  699797.0     14845  644621963  371966522.1  cudaMalloc
#       0.3          1922723          2     961361.5  961361.5    132689    1790034    1171919.9  cudaLaunchKernel
#       0.3          1664925          2     832462.5  832462.5    101072    1563853    1034342.4  cudaMemcpy
#       0.2          1549667          3     516555.7  684595.0     29595     835477     428414.9  cudaFree
#       0.0            78839          1      78839.0   78839.0     78839      78839          0.0  cuLibraryUnload
#       0.0             8313          1       8313.0    8313.0      8313       8313          0.0  cuCtxSynchronize
#       0.0             5531          1       5531.0    5531.0      5531       5531          0.0  cuModuleGetLoadingMode
#       0.0              748          1        748.0     748.0       748        748          0.0  cuDeviceGetLuid
#
# [4/6] Executing 'cuda_gpu_kern_sum' stats report
#
#  Time (%)  Total Time (ns)  Instances  Avg (ns)  Med (ns)  Min (ns)  Max (ns)  StdDev (ns)                                              Name
#  --------  ---------------  ---------  --------  --------  --------  --------  -----------  ---------------------------------------------------------------------------------------------
#      52.3            20321          1   20321.0   20321.0     20321     20321          0.0  reduce2DTo1D(double *, double *, unsigned long long, unsigned long long)
#      47.7            18561          1   18561.0   18561.0     18561     18561          0.0  sumZDimension(double *, double *, unsigned long long, unsigned long long, unsigned long long)
#
# [5/6] Executing 'cuda_gpu_mem_time_sum' stats report
#
#  Time (%)  Total Time (ns)  Count  Avg (ns)   Med (ns)   Min (ns)  Max (ns)  StdDev (ns)           Operation
#  --------  ---------------  -----  ---------  ---------  --------  --------  -----------  ----------------------------
#      99.9          1239057      1  1239057.0  1239057.0   1239057   1239057          0.0  [CUDA memcpy Host-to-Device]
#       0.1             1408      1     1408.0     1408.0      1408      1408          0.0  [CUDA memcpy Device-to-Host]
#
# [6/6] Executing 'cuda_gpu_mem_size_sum' stats report
#
#  Total (MB)  Count  Avg (MB)  Med (MB)  Min (MB)  Max (MB)  StdDev (MB)           Operation
#  ----------  -----  --------  --------  --------  --------  -----------  ----------------------------
#       8.000      1     8.000     8.000     8.000     8.000        0.000  [CUDA memcpy Host-to-Device]
#       0.001      1     0.001     0.001     0.001     0.001        0.000  [CUDA memcpy Device-to-Host]
#
# Generated:
#     e:\02_Learn\01_University\Senior-1 Spring\Current\Parallel Computing\Labs\Lab_3\Solution\profile_k2_t2_50.nsys-rep
#     e:\02_Learn\01_University\Senior-1 Spring\Current\Parallel Computing\Labs\Lab_3\Solution\profile_k2_t2_50.sqlite

# %% [markdown]
# ### **Requriment - 3**
# - Use multiple blocks for your kernal and let the CPU handle the final sum.

# %%
compile_and_run_kernel(3, "t2_50", analytics=True)
# Out:
# ^C
# Block 5: sharedSum[0] = -51364.735000
# Block 2: sharedSum[0] = 224510.394000
# Block 4: sharedSum[0] = 34191.373000
# Block 1: sharedSum[0] = 72056.736000
# Block 3: sharedSum[0] = 27260.010000
# Block 0: sharedSum[0] = 126479.878000
# Block 6: sharedSum[0] = -55551.030000
# Kernel sumZDimension Started
# Kernel reduce2DTo1D Started
# Error opening file ../Output_TestCases/1d_kernel3.txt
# 'e:\\02_Learn\\01_University\\Senior-1 Spring\\Current\\Parallel Computing\\Labs\\Lab_3\\Solution\\Output_TestCases/t2_50_k3_o.txt'
# kernel3.cu
# tmpxft_00003b34_00000000-10_kernel3.cudafe1.cpp
#    Creating library e:\02_Learn\01_University\Senior-1 Spring\Current\Parallel Computing\Labs\Lab_3\Solution\cuda_kernels\bin\kernel3.lib and object e:\02_Learn\01_University\Senior-1 Spring\Current\Parallel Computing\Labs\Lab_3\Solution\cuda_kernels\bin\kernel3.exp
